# %%
import pandas as pd

# %%
inspections = pd.read_csv("/home/jczestochowska/workspace/ada/chicago_food/data/raw/food-inspections.csv")

# %%
inspections.Risk.unique()
# Out:
# array(['Risk 1 (High)', 'Risk 3 (Low)', 'Risk 2 (Medium)', nan, 'All'],
#       dtype=object)

# %%
inspections = inspections.dropna(subset=["Facility Type"])

# %%
inspections = inspections[inspections["Facility Type"].str.contains("restaurant", case=False)]

# %%
inspections[inspections.Risk == 'All'].index
# Out:
# Int64Index([376, 4908, 5019, 20100, 29051, 47069, 108509, 118221], dtype='int64')

# %%
inspections = inspections.drop(inspections[inspections.Risk == 'All'].index)

# %%
inspections.Results.unique()
# Out:
# array(['Pass w/ Conditions', 'Out of Business', 'Pass', 'Fail',
#        'No Entry', 'Not Ready', 'Business Not Located'], dtype=object)

# %%
inspections = inspections[inspections.Results.isin(['Pass w/ Conditions', 'Pass','Fail'])]

# %%
inspections.head()
# Out:
#    Inspection ID               DBA Name               AKA Name  License #  \
# 1        2320342      YOLK TEST KITCHEN      YOLK TEST KITCHEN  2589655.0
# 3        2320319            LA PALAPITA            LA PALAPITA  2694702.0
# 5        2320261             CRAZY BIRD             CRAZY BIRD  2616198.0
# 6        2320245  THE REDHEAD PIANO BAR  THE REDHEAD PIANO BAR  2313945.0
# 7        2320298                HAISOUS              CA PHE DA  2464411.0
#
#   Facility Type           Risk                    Address     City State  \
# 1    Restaurant  Risk 1 (High)      1767 N MILWAUKEE AVE   CHICAGO    IL
# 3    Restaurant  Risk 1 (High)            3834 W 47TH ST   CHICAGO    IL
# 5    Restaurant  Risk 1 (High)          1160 W GRAND AVE   CHICAGO    IL
# 6    Restaurant   Risk 3 (Low)        16-18 W ONTARIO ST   CHICAGO    IL
# 7    Restaurant  Risk 1 (High)  1800-1802 S CARPENTER ST   CHICAGO    IL
#
#        Zip  ...             Results  \
# 1  60647.0  ...  Pass w/ Conditions
# ...

# %%
inspections[inspections.Risk.isna()]
# Out:
#         Inspection ID            DBA Name            AKA Name  License #  \
# 110530        1459985    GREENLINE COFFEE    GREENLINE COFFEE  2333150.0
# 155746         670575    RESPECT FOR LIFE    RESPECT FOR LIFE        0.0
# 182076         413465  JW MARRIOT CHICAGO  JW MARRIOT CHICAGO        0.0
#
#        Facility Type Risk          Address     City State      Zip  ...  \
# 110530    Restaurant  NaN   501 E 61ST ST   CHICAGO    IL  60637.0  ...
# 155746    Restaurant  NaN   725 W 79TH ST   CHICAGO    IL  60620.0  ...
# 182076    Restaurant  NaN  151 W Adams ST   CHICAGO    IL  60603.0  ...
#
#        Results Violations   Latitude  Longitude  \
# 110530    Fail        NaN  41.783819 -87.613189
# 155746    Fail        NaN  41.750553 -87.642674
# 182076    Fail        NaN  41.879290 -87.632363
#
#                                                  Location  \
# 110530  {'longitude': '41.783819303359486', 'latitude'...
# 155746  {'longitude': '41.75055282036361', 'latitude':...
# ...

# %%
inspections = inspections.dropna(subset=["Risk"])

# %% [markdown]
# ## We change Risk 1 (High) to 1 and Risk 3 (Low) to 3

# %%
inspections.Risk = inspections.Risk.map({'Risk 1 (High)': 1, 'Risk 3 (Low)': 3, 'Risk 2 (Medium)': 2})

# %%
inspections.head()
# Out:
#    Inspection ID               DBA Name               AKA Name  License #  \
# 1        2320342      YOLK TEST KITCHEN      YOLK TEST KITCHEN  2589655.0
# 3        2320319            LA PALAPITA            LA PALAPITA  2694702.0
# 5        2320261             CRAZY BIRD             CRAZY BIRD  2616198.0
# 6        2320245  THE REDHEAD PIANO BAR  THE REDHEAD PIANO BAR  2313945.0
# 7        2320298                HAISOUS              CA PHE DA  2464411.0
#
#   Facility Type  Risk                    Address     City State      Zip  ...  \
# 1    Restaurant     1      1767 N MILWAUKEE AVE   CHICAGO    IL  60647.0  ...
# 3    Restaurant     1            3834 W 47TH ST   CHICAGO    IL  60632.0  ...
# 5    Restaurant     1          1160 W GRAND AVE   CHICAGO    IL  60642.0  ...
# 6    Restaurant     3        16-18 W ONTARIO ST   CHICAGO    IL  60654.0  ...
# 7    Restaurant     1  1800-1802 S CARPENTER ST   CHICAGO    IL  60608.0  ...
#
# ...
