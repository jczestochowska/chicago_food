# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('data/google_places.csv', index_col=0)
data.head()
# Out:
#                                         place_name  rating  \
# place_id
# ChIJleWegJHTD4gRsIMGm3IjUcM    yolk - test kitchen     4.4
# ChIJI1dehI0xDogRRkvKIpUspHM  las asadas restaurant     4.0
# ChIJBRuLGC_MD4gRfUVkzaQBIZk          mini palapita     4.3
# ChIJ-auSyWItDogRQwUqcwljejE     crazy bird chicken     4.7
# ChIJIYRFg7IsDogRAW0zLguKL-A      redhead piano bar     4.2
#
#                              total_number_of_ratings  price_level  \
# place_id
# ChIJleWegJHTD4gRsIMGm3IjUcM                    180.0          2.0
# ChIJI1dehI0xDogRRkvKIpUspHM                    166.0          2.0
# ChIJBRuLGC_MD4gRfUVkzaQBIZk                    342.0          1.0
# ChIJ-auSyWItDogRQwUqcwljejE                     67.0          NaN
# ChIJIYRFg7IsDogRAW0zLguKL-A                    989.0          2.0
#
#                                           address     city    zip_code
# place_id
# ChIJleWegJHTD4gRsIMGm3IjUcM  1767 n milwaukee ave  chicago       60647
# ...

# %%
data.shape
# Out:
# (13006, 7)

# %%
data[data.price_level.isna()].shape
# Out:
# (5079, 7)

# %%
data[data.rating.isna()].shape
# Out:
# (728, 7)

# %%
data["rating"].unique
# Out:
# <bound method Series.unique of place_id
# ChIJleWegJHTD4gRsIMGm3IjUcM    4.4
# ChIJI1dehI0xDogRRkvKIpUspHM    4.0
# ChIJBRuLGC_MD4gRfUVkzaQBIZk    4.3
# ChIJ-auSyWItDogRQwUqcwljejE    4.7
# ChIJIYRFg7IsDogRAW0zLguKL-A    4.2
#                               ...
# ChIJIVSzGQ3nEYgR8nZhwaBQ9ZM    3.6
# ChIJ5fNghEVMDogR4UWYi3iHLPE    NaN
# ChIJtf1ZQfzqEYgR9gh_2CPqkNE    4.0
# ChIJ6a1jjZssDogR3PQwtmza-vs    3.5
# ChIJubeVEQrTD4gRVKoy9DuCqsQ    NaN
# Name: rating, Length: 13006, dtype: float64>

# %%
data.reset_index(level=0,inplace=True)
data.head()
# Out:
#                       place_id             place_name  rating  \
# 0  ChIJleWegJHTD4gRsIMGm3IjUcM    yolk - test kitchen     4.4
# 1  ChIJI1dehI0xDogRRkvKIpUspHM  las asadas restaurant     4.0
# 2  ChIJBRuLGC_MD4gRfUVkzaQBIZk          mini palapita     4.3
# 3  ChIJ-auSyWItDogRQwUqcwljejE     crazy bird chicken     4.7
# 4  ChIJIYRFg7IsDogRAW0zLguKL-A      redhead piano bar     4.2
#
#    total_number_of_ratings  price_level               address     city  \
# 0                    180.0          2.0  1767 n milwaukee ave  chicago
# 1                    166.0          2.0        3834 w 47th st  chicago
# 2                    342.0          1.0     4968 n elston ave  chicago
# 3                     67.0          NaN      1160 w grand ave  chicago
# 4                    989.0          2.0       16 w ontario st  chicago
#
#      zip_code
# 0       60647
# 1  60632-4136
# 2       60630
# 3  60642-5837
# 4       60654

# %%
data[data.city == 'london']
# Out:
#                           place_id                             place_name  \
# 2313   ChIJkbk0TvsQdkgRf-Bzbmzb7C0                    wing tai restaurant
# 5362   ChIJ-5WkAyAFdkgRIrEdoX2CpXU                                   tozi
# 6031   ChIJsz4-b0AFdkgRmaEzfghxSIY                          walton street
# 6985   ChIJL1PqC4wcdkgRdwLj45QtnkU                   mangal turkish pizza
# 9390   ChIJ74DrmWgEdkgRmsDo0R0P2Ts  carioca - brazilian cuisine (brixton)
# 11134  ChIJ61CLYvjxLogRJoxRljVsB2Y                         villa cornelia
#
#        rating  total_number_of_ratings  price_level                address  \
# 2313      4.0                    571.0          2.0         395 edgware rd
# 5362      4.5                    953.0          3.0        8 gillingham st
# 6031      NaN                      NaN          NaN              walton st
# 6985      4.6                     72.0          1.0  27 stoke newington rd
# ...

# %%
pd.read_pickle("violations_after_change.pickle")#['Description'].values
# Out:
#     Code                                        Description
# 0      1  PERSON IN CHARGE PRESENT, DEMONSTRATES KNOWLED...
# 11     2  CITY OF CHICAGO FOOD SERVICE SANITATION CERTIF...
# 22     3  MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPL...
# 41     5  PROCEDURES FOR RESPONDING TO VOMITING AND DIAR...
# 52     6   PROPER EATING, TASTING, DRINKING, OR TOBACCO USE
# 57     7            NO DISCHARGE FROM EYES, NOSE, AND MOUTH
# 58     8                      HANDS CLEAN & PROPERLY WASHED
# 59     9  NO BARE HAND CONTACT WITH RTE FOOD OR A PRE-AP...
# 1     10  ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED A...
# 2     11                 FOOD OBTAINED FROM APPROVED SOURCE
# 3     12                FOOD RECEIVED AT PROPER TEMPERATURE
# 4     13      FOOD IN GOOD CONDITION, SAFE, & UNADULTERATED
# 5     14  REQUIRED RECORDS AVAILABLE: SHELLSTOCK TAGS, P...
# 6     15                       FOOD SEPARATED AND PROTECTED
# 7     16         FOOD-CONTACT SURFACES: CLEANED & SANITIZED
# ...
